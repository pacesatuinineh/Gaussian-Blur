# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Gaussian-Blur/blob/main/Komb2VGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
#from efficientnet.tfkeras import EfficientNetB0
from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
data_path = "/content/drive/MyDrive/modifdataset"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(haar_image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    #base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    #rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.5,
    #zoom_range=0.5,
    #horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    #fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_and_preprocess_images(data_path)
test_images, test_labels = load_and_preprocess_images(data_path)

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.1773 - loss: 12.4651 - val_accuracy: 0.2037 - val_loss: 13.5755 - learning_rate: 1.0000e-04
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 618ms/step - accuracy: 0.2016 - loss: 11.8668 - val_accuracy: 0.2037 - val_loss: 13.3214 - learning_rate: 1.0000e-04
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.1979 - loss: 11.5656 - val_accuracy: 0.1971 - val_loss: 11.6525 - learning_rate: 1.0000e-04
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.1947 - loss: 11.2491 - val_accuracy: 0.1978 - val_loss: 11.1287 - learning_rate: 1.0000e-04
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.1997 - loss: 10.9447 - val_accuracy: 0.2050 - val_loss: 10.8444 - learning_rate: 1.0000e-04
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.2179 - loss: 10.6683 - val_accuracy: 0.1762 - val_loss: 13.2785 - learning_rate: 1.0000e-04
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.1933 - loss: 10.3624 - val_accuracy: 0.1965 - val_loss: 10.2572 - learning_rate: 1.0000e-04
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.1954 - loss: 10.0776 - val_accuracy: 0.2030 - val_loss: 9.8918 - learning_rate: 1.0000e-04
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.1917 - loss: 9.7651 - val_accuracy: 0.1971 - val_loss: 9.6381 - learning_rate: 1.0000e-04
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.2210 - loss: 9.4863 - val_accuracy: 0.1978 - val_loss: 9.2390 - learning_rate: 1.0000e-04
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.1982 - loss: 9.1911 - val_accuracy: 0.2017 - val_loss: 8.9600 - learning_rate: 1.0000e-04
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2013 - loss: 8.9167 - val_accuracy: 0.2089 - val_loss: 8.6788 - learning_rate: 1.0000e-04
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.2045 - loss: 8.6362 - val_accuracy: 0.2069 - val_loss: 8.4133 - learning_rate: 1.0000e-04
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.1794 - loss: 8.3715 - val_accuracy: 0.2004 - val_loss: 8.1440 - learning_rate: 1.0000e-04
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2252 - loss: 8.0901 - val_accuracy: 0.2056 - val_loss: 7.8771 - learning_rate: 1.0000e-04
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.1970 - loss: 7.8485 - val_accuracy: 0.1965 - val_loss: 7.6229 - learning_rate: 1.0000e-04
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.1796 - loss: 7.5884 - val_accuracy: 0.1978 - val_loss: 7.3790 - learning_rate: 1.0000e-04
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2146 - loss: 7.3337 - val_accuracy: 0.2102 - val_loss: 7.1436 - learning_rate: 1.0000e-04
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.1972 - loss: 7.0834 - val_accuracy: 0.2089 - val_loss: 6.9094 - learning_rate: 1.0000e-04
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2112 - loss: 6.8598 - val_accuracy: 0.2056 - val_loss: 6.6876 - learning_rate: 1.0000e-04
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.2016 - loss: 6.6492 - val_accuracy: 0.2213 - val_loss: 6.4676 - learning_rate: 1.0000e-04
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.1987 - loss: 6.4347 - val_accuracy: 0.1696 - val_loss: 6.2687 - learning_rate: 1.0000e-04
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.2057 - loss: 6.2215 - val_accuracy: 0.1565 - val_loss: 6.0763 - learning_rate: 1.0000e-04
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2051 - loss: 6.0210 - val_accuracy: 0.2358 - val_loss: 5.8532 - learning_rate: 1.0000e-04
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2128 - loss: 5.8137 - val_accuracy: 0.2266 - val_loss: 5.6611 - learning_rate: 1.0000e-04
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2193 - loss: 5.6365 - val_accuracy: 0.1860 - val_loss: 5.4934 - learning_rate: 1.0000e-04
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2179 - loss: 5.4596 - val_accuracy: 0.2547 - val_loss: 5.3051 - learning_rate: 1.0000e-04
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 618ms/step - accuracy: 0.2019 - loss: 5.2819 - val_accuracy: 0.2371 - val_loss: 5.1542 - learning_rate: 1.0000e-04
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2221 - loss: 5.1136 - val_accuracy: 0.1984 - val_loss: 4.9845 - learning_rate: 1.0000e-04
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2266 - loss: 4.9553 - val_accuracy: 0.2083 - val_loss: 4.8342 - learning_rate: 1.0000e-04
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 615ms/step - accuracy: 0.1920 - loss: 4.7940 - val_accuracy: 0.2017 - val_loss: 4.6868 - learning_rate: 1.0000e-04
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2002 - loss: 4.6662 - val_accuracy: 0.2482 - val_loss: 4.5292 - learning_rate: 1.0000e-04
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2239 - loss: 4.5155 - val_accuracy: 0.1709 - val_loss: 4.4459 - learning_rate: 1.0000e-04
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.1980 - loss: 4.3789 - val_accuracy: 0.1794 - val_loss: 4.3192 - learning_rate: 1.0000e-04
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2339 - loss: 4.2481 - val_accuracy: 0.2443 - val_loss: 4.1348 - learning_rate: 1.0000e-04
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2179 - loss: 4.1318 - val_accuracy: 0.2358 - val_loss: 4.0212 - learning_rate: 1.0000e-04
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2333 - loss: 3.9969 - val_accuracy: 0.2554 - val_loss: 3.8917 - learning_rate: 1.0000e-04
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2380 - loss: 3.8844 - val_accuracy: 0.2056 - val_loss: 3.8121 - learning_rate: 1.0000e-04
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 618ms/step - accuracy: 0.2279 - loss: 3.7823 - val_accuracy: 0.2351 - val_loss: 3.6853 - learning_rate: 1.0000e-04
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2396 - loss: 3.6454 - val_accuracy: 0.2233 - val_loss: 3.5809 - learning_rate: 1.0000e-04
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2310 - loss: 3.5535 - val_accuracy: 0.2456 - val_loss: 3.5979 - learning_rate: 1.0000e-04
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2334 - loss: 3.4604 - val_accuracy: 0.2161 - val_loss: 3.4145 - learning_rate: 1.0000e-04
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2446 - loss: 3.3815 - val_accuracy: 0.1644 - val_loss: 3.3763 - learning_rate: 1.0000e-04
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 615ms/step - accuracy: 0.2263 - loss: 3.2695 - val_accuracy: 0.1637 - val_loss: 3.2921 - learning_rate: 1.0000e-04
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2230 - loss: 3.1906 - val_accuracy: 0.2377 - val_loss: 3.1255 - learning_rate: 1.0000e-04
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2446 - loss: 3.1154 - val_accuracy: 0.2626 - val_loss: 3.0230 - learning_rate: 1.0000e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 617ms/step - accuracy: 0.2372 - loss: 3.0421 - val_accuracy: 0.2161 - val_loss: 2.9793 - learning_rate: 1.0000e-04
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2481 - loss: 2.9338 - val_accuracy: 0.2056 - val_loss: 2.9271 - learning_rate: 1.0000e-04
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 615ms/step - accuracy: 0.2580 - loss: 2.8702 - val_accuracy: 0.1991 - val_loss: 2.9990 - learning_rate: 1.0000e-04
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2593 - loss: 2.8183 - val_accuracy: 0.1650 - val_loss: 2.8736 - learning_rate: 1.0000e-04
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2531 - loss: 2.7285 - val_accuracy: 0.1565 - val_loss: 2.8546 - learning_rate: 1.0000e-04
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2581 - loss: 2.6670 - val_accuracy: 0.1670 - val_loss: 2.6997 - learning_rate: 1.0000e-04
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2661 - loss: 2.6124 - val_accuracy: 0.1585 - val_loss: 2.7321 - learning_rate: 1.0000e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.2666 - loss: 2.5294 - val_accuracy: 0.2528 - val_loss: 2.4664 - learning_rate: 1.0000e-04
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2389 - loss: 2.4771 - val_accuracy: 0.1729 - val_loss: 2.6325 - learning_rate: 1.0000e-04
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.2756 - loss: 2.3731 - val_accuracy: 0.1670 - val_loss: 2.5977 - learning_rate: 1.0000e-04
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.2766 - loss: 2.3348 - val_accuracy: 0.2083 - val_loss: 2.5026 - learning_rate: 1.0000e-04
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 616ms/step - accuracy: 0.2964 - loss: 2.2504 - val_accuracy: 0.3366 - val_loss: 2.2104 - learning_rate: 1.0000e-04
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.2975 - loss: 2.1815 - val_accuracy: 0.1984 - val_loss: 2.6876 - learning_rate: 1.0000e-04
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.3155 - loss: 2.1538 - val_accuracy: 0.3012 - val_loss: 2.2216 - learning_rate: 1.0000e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.3453 - loss: 2.0688 - val_accuracy: 0.2050 - val_loss: 3.1268 - learning_rate: 1.0000e-04
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.3348 - loss: 2.0100 - val_accuracy: 0.3196 - val_loss: 2.0094 - learning_rate: 1.0000e-04
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 614ms/step - accuracy: 0.3578 - loss: 1.9237 - val_accuracy: 0.3615 - val_loss: 1.9064 - learning_rate: 1.0000e-04
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.3908 - loss: 1.8821 - val_accuracy: 0.2750 - val_loss: 2.3685 - learning_rate: 1.0000e-04
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.4141 - loss: 1.7956 - val_accuracy: 0.1978 - val_loss: 5.0824 - learning_rate: 1.0000e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 615ms/step - accuracy: 0.3857 - loss: 1.7939 - val_accuracy: 0.2731 - val_loss: 2.4266 - learning_rate: 1.0000e-04
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.4328 - loss: 1.7003 - val_accuracy: 0.3955 - val_loss: 1.7662 - learning_rate: 1.0000e-04
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.4758 - loss: 1.5759 - val_accuracy: 0.2770 - val_loss: 2.7055 - learning_rate: 1.0000e-04
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.4527 - loss: 1.5481 - val_accuracy: 0.5246 - val_loss: 1.4290 - learning_rate: 1.0000e-04
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.4958 - loss: 1.4929 - val_accuracy: 0.5462 - val_loss: 1.3475 - learning_rate: 1.0000e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.5184 - loss: 1.4073 - val_accuracy: 0.4348 - val_loss: 1.5978 - learning_rate: 1.0000e-04
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.4957 - loss: 1.3769 - val_accuracy: 0.4158 - val_loss: 1.6436 - learning_rate: 1.0000e-04
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.5521 - loss: 1.2521 - val_accuracy: 0.5966 - val_loss: 1.2090 - learning_rate: 1.0000e-04
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 611ms/step - accuracy: 0.5627 - loss: 1.2384 - val_accuracy: 0.4545 - val_loss: 1.6759 - learning_rate: 1.0000e-04
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.4989 - loss: 1.3197 - val_accuracy: 0.2914 - val_loss: 3.0303 - learning_rate: 1.0000e-04
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.5759 - loss: 1.1347 - val_accuracy: 0.2954 - val_loss: 2.8027 - learning_rate: 1.0000e-04
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.5914 - loss: 1.1021 - val_accuracy: 0.5494 - val_loss: 1.1979 - learning_rate: 1.0000e-04
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.5970 - loss: 1.0931 - val_accuracy: 0.5553 - val_loss: 1.1707 - learning_rate: 1.0000e-04
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.6051 - loss: 1.0931 - val_accuracy: 0.2403 - val_loss: 3.6833 - learning_rate: 1.0000e-04
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.6194 - loss: 1.0454 - val_accuracy: 0.4407 - val_loss: 2.0148 - learning_rate: 1.0000e-04
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.5950 - loss: 1.0468 - val_accuracy: 0.6830 - val_loss: 1.0467 - learning_rate: 1.0000e-04
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 611ms/step - accuracy: 0.6716 - loss: 0.9450 - val_accuracy: 0.7531 - val_loss: 0.8316 - learning_rate: 1.0000e-04
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.6964 - loss: 0.9120 - val_accuracy: 0.5999 - val_loss: 1.1062 - learning_rate: 1.0000e-04
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 611ms/step - accuracy: 0.7392 - loss: 0.8477 - val_accuracy: 0.7400 - val_loss: 0.8004 - learning_rate: 1.0000e-04
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 613ms/step - accuracy: 0.7403 - loss: 0.8720 - val_accuracy: 0.7701 - val_loss: 0.7915 - learning_rate: 1.0000e-04
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 611ms/step - accuracy: 0.7794 - loss: 0.7575 - val_accuracy: 0.6817 - val_loss: 0.9891 - learning_rate: 1.0000e-04
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 611ms/step - accuracy: 0.7938 - loss: 0.7318 - val_accuracy: 0.7472 - val_loss: 0.7871 - learning_rate: 1.0000e-04
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.8085 - loss: 0.7063 - val_accuracy: 0.7819 - val_loss: 0.7901 - learning_rate: 1.0000e-04
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 612ms/step - accuracy: 0.8386 - loss: 0.6467 - val_accuracy: 0.8546 - val_loss: 0.5942 - learning_rate: 1.0000e-04
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 611ms/step - accuracy: 0.8431 - loss: 0.6286 - val_accuracy: 0.5868 - val_loss: 1.4232 - learning_rate: 1.0000e-04
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.8928 - loss: 0.5012 - val_accuracy: 0.8114 - val_loss: 0.7440 - learning_rate: 1.0000e-04
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.8843 - loss: 0.5617 - val_accuracy: 0.8016 - val_loss: 0.6625 - learning_rate: 1.0000e-04
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.9031 - loss: 0.4991 - val_accuracy: 0.6929 - val_loss: 1.1795 - learning_rate: 1.0000e-04
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.8783 - loss: 0.4993 - val_accuracy: 0.8029 - val_loss: 0.6746 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step
#               precision    recall  f1-score   support
#
#      Aitinyo       0.94      0.72      0.81       374
#      Ayamaru       0.93      0.76      0.84       311
#       Kokoda       1.00      0.88      0.93       302
#          Moi       0.75      0.99      0.85       301
#        Tehit       0.73      1.00      0.84       239
#
#     accuracy                           0.85      1527
#    macro avg       0.87      0.87      0.86      1527
# weighted avg       0.88      0.85      0.85      1527
