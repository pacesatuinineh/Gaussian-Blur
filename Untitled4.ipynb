# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Gaussian-Blur/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** Inisialisasi dan Setup**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install -U --pre efficientnet
from efficientnet.tfkeras import EfficientNetB1
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import seaborn as sns
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
import cv2
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: efficientnet in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.25.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.5.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.0)

# %% [markdown]
# # **Memuat dan Memproses Data**

# %%
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
IMAGE_SIZE = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3

# path = "/content/drive/MyDrive/Split_data/suku9/train"
path = "/content/drive/MyDrive/suku12/train"
lists_dir = os.listdir(path)
categories = []
file_name = []
for folder in lists_dir:
    files = os.listdir(path + "/" + folder)
    for file in files:
        path_file = path + "/" + folder + "/" + file
        file_name.append(path_file)
        categories.append(folder)

df = {"image": file_name, "categories": categories}
data = pd.DataFrame(df, index=None)
data = data.sample(frac=1)
data.head(5)

# Precompute Gaussian Blur and save images
blurred_images_path = '/content/blurred_images/train/'
os.makedirs(blurred_images_path, exist_ok=True)

blurred_file_paths = []
for i, row in data.iterrows():
    img = cv2.imread(row['image'])
    img_blur = cv2.GaussianBlur(img, (3, 33), 0)
    new_path = os.path.join(blurred_images_path, os.path.basename(row['image']))
    cv2.imwrite(new_path, img_blur)
    blurred_file_paths.append(new_path)

data['blurred_image'] = blurred_file_paths

# path_datatest = "/content/drive/MyDrive/Split_data/suku9/test"
path_datatest = "/content/drive/MyDrive/suku12/test"
lists_dir_datatest = os.listdir(path_datatest)
categories_datatest = []
file_name_datatest = []
for folder in lists_dir_datatest:
    files = os.listdir(path_datatest + "/" + folder)
    for file in files:
        path_file = path_datatest + "/" + folder + "/" + file
        file_name_datatest.append(path_file)
        categories_datatest.append(folder)

df_datatest = {"image": file_name_datatest, "categories": categories_datatest}
data_datatest = pd.DataFrame(df_datatest, index=None)
data_datatest = data_datatest.sample(frac=1)
nb_samples = data_datatest.shape[0]
data_datatest

# Precompute Gaussian Blur and save images for test set
blurred_images_test_path = '/content/blurred_images/test/'
os.makedirs(blurred_images_test_path, exist_ok=True)

blurred_test_file_paths = []
for i, row in data_datatest.iterrows():
    img = cv2.imread(row['image'])
    img_blur = cv2.GaussianBlur(img, (3, 33), 0)
    new_path = os.path.join(blurred_images_test_path, os.path.basename(row['image']))
    cv2.imwrite(new_path, img_blur)
    blurred_test_file_paths.append(new_path)

data_datatest['blurred_image'] = blurred_test_file_paths

data['categories'].value_counts().plot.bar()

total_dataset = len(data_datatest) + len(data)
print("Total dataset Suku: {} Suku".format(total_dataset))

data["categories"] = data["categories"].replace({0: 'moi', 1: 'nonmoi'})

train_df, validate_df = train_test_split(data, test_size=0.10, random_state=20)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

train_df['categories'].value_counts().plot.bar()
validate_df['categories'].value_counts().plot.bar()
# Out:
# Total dataset Suku: 637 Suku
# <Axes: xlabel='categories'>

# %% [markdown]
# # **Mempersiapkan ImageDataGenerator tanpa Gaussian Blur**

# %%
train_datagen = ImageDataGenerator(
    rotation_range=30,
    rescale=1./255,
    shear_range=0.1,
    vertical_flip=True,
    zoom_range=0.2,
)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=None,  # Specify directory as None because full paths are provided in 'blurred_image'
    x_col='blurred_image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)

validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=validate_df,
    directory=None,  # Specify directory as None because full paths are provided in 'blurred_image'
    x_col='blurred_image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 459 validated image filenames belonging to 2 classes.
# Found 52 validated image filenames belonging to 2 classes.

# %% [markdown]
# # **Visualisasi Data**

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    dataframe=example_df,
    directory=None,  # Specify directory as None because full paths are provided in 'blurred_image'
    x_col='blurred_image',
    y_col='categories',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)

plt.figure(figsize=(12, 12))
for i in range(0, 10):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %% [markdown]
# # **Membuat dan Melatih Model**

# %%
base_model = EfficientNetB1(input_shape=(224, 224, 3),
                            include_top=False,
                            weights='noisy-student')

for layer in base_model.layers:
    layer.trainable = False

model = Sequential()
model.add(base_model)
model.add(Conv2D(640, kernel_size=(1, 1)))
model.add(Flatten())
model.add(Dense(320, kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(tf.keras.layers.ReLU())
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))

model.compile("adam", loss="binary_crossentropy", metrics=["accuracy"])
model.summary()

epochs = 30
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=1
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnet-b1 (Functiona  (None, 7, 7, 1280)        6575232
#  l)
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 640)         819840
#
#  flatten_1 (Flatten)         (None, 31360)             0
#
#  dense_2 (Dense)             (None, 320)               10035520
#
#  batch_normalization_1 (Bat  (None, 320)               1280
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 320)               0
#
#  dropout_1 (Dropout)         (None, 320)               0
#
#  dense_3 (Dense)             (None, 2)                 642
#
# =================================================================
# Total params: 17432514 (66.50 MB)
# Trainable params: 10856642 (41.41 MB)
# Non-trainable params: 6575872 (25.08 MB)
# _________________________________________________________________
# Epoch 1/30
# 8/8 [==============================] - 19s 1s/step - loss: 0.8912 - accuracy: 0.6383 - val_loss: 1.3853 - val_accuracy: 0.7692
# Epoch 2/30
# 8/8 [==============================] - 7s 938ms/step - loss: 0.4366 - accuracy: 0.8105 - val_loss: 2.9552 - val_accuracy: 0.7115
# Epoch 3/30
# 8/8 [==============================] - 6s 779ms/step - loss: 0.3404 - accuracy: 0.8497 - val_loss: 1.0662 - val_accuracy: 0.8077
# Epoch 4/30
# 8/8 [==============================] - 7s 807ms/step - loss: 0.2771 - accuracy: 0.8911 - val_loss: 0.7493 - val_accuracy: 0.8269
# Epoch 5/30
# 8/8 [==============================] - 7s 824ms/step - loss: 0.2774 - accuracy: 0.8954 - val_loss: 0.7706 - val_accuracy: 0.8269
# Epoch 6/30
# 8/8 [==============================] - 7s 798ms/step - loss: 0.2252 - accuracy: 0.9129 - val_loss: 0.7001 - val_accuracy: 0.8269
# Epoch 7/30
# 8/8 [==============================] - 7s 816ms/step - loss: 0.1929 - accuracy: 0.9259 - val_loss: 0.2799 - val_accuracy: 0.8846
# Epoch 8/30
# 8/8 [==============================] - 7s 791ms/step - loss: 0.1580 - accuracy: 0.9455 - val_loss: 0.1894 - val_accuracy: 0.9038
# Epoch 9/30
# 8/8 [==============================] - 7s 813ms/step - loss: 0.1925 - accuracy: 0.9303 - val_loss: 0.1531 - val_accuracy: 0.9423
# Epoch 10/30
# 8/8 [==============================] - 7s 832ms/step - loss: 0.1803 - accuracy: 0.9412 - val_loss: 0.1454 - val_accuracy: 0.9423
# Epoch 11/30
# 8/8 [==============================] - 7s 818ms/step - loss: 0.1918 - accuracy: 0.9216 - val_loss: 0.1668 - val_accuracy: 0.9231
# Epoch 12/30
# 8/8 [==============================] - 7s 920ms/step - loss: 0.2051 - accuracy: 0.9150 - val_loss: 0.1455 - val_accuracy: 0.9615
# Epoch 13/30
# 8/8 [==============================] - 7s 812ms/step - loss: 0.1321 - accuracy: 0.9542 - val_loss: 0.1996 - val_accuracy: 0.8846
# Epoch 14/30
# 8/8 [==============================] - 7s 822ms/step - loss: 0.1409 - accuracy: 0.9542 - val_loss: 0.6324 - val_accuracy: 0.8077
# Epoch 15/30
# 8/8 [==============================] - 7s 824ms/step - loss: 0.1378 - accuracy: 0.9542 - val_loss: 0.6678 - val_accuracy: 0.8077
# Epoch 16/30
# 8/8 [==============================] - 7s 811ms/step - loss: 0.1398 - accuracy: 0.9412 - val_loss: 0.2747 - val_accuracy: 0.8654
# Epoch 17/30
# 8/8 [==============================] - 7s 810ms/step - loss: 0.1672 - accuracy: 0.9281 - val_loss: 0.6644 - val_accuracy: 0.8269
# Epoch 18/30
# 8/8 [==============================] - 7s 814ms/step - loss: 0.1278 - accuracy: 0.9499 - val_loss: 0.2042 - val_accuracy: 0.9038
# Epoch 19/30
# 8/8 [==============================] - 7s 931ms/step - loss: 0.1660 - accuracy: 0.9368 - val_loss: 0.2150 - val_accuracy: 0.9231
# Epoch 20/30
# 8/8 [==============================] - 7s 802ms/step - loss: 0.1247 - accuracy: 0.9630 - val_loss: 0.1232 - val_accuracy: 0.9615
# Epoch 21/30
# 8/8 [==============================] - 7s 798ms/step - loss: 0.1404 - accuracy: 0.9455 - val_loss: 0.1022 - val_accuracy: 0.9615
# Epoch 22/30
# 8/8 [==============================] - 7s 809ms/step - loss: 0.1488 - accuracy: 0.9390 - val_loss: 0.1537 - val_accuracy: 0.9231
# Epoch 23/30
# 8/8 [==============================] - 7s 811ms/step - loss: 0.1341 - accuracy: 0.9477 - val_loss: 0.3248 - val_accuracy: 0.8269
# Epoch 24/30
# 8/8 [==============================] - 7s 808ms/step - loss: 0.1287 - accuracy: 0.9521 - val_loss: 0.1980 - val_accuracy: 0.9038
# Epoch 25/30
# 8/8 [==============================] - 7s 807ms/step - loss: 0.1051 - accuracy: 0.9673 - val_loss: 0.2017 - val_accuracy: 0.8654
# Epoch 26/30
# 8/8 [==============================] - 7s 931ms/step - loss: 0.1110 - accuracy: 0.9630 - val_loss: 0.3846 - val_accuracy: 0.8462
# Epoch 27/30
# 8/8 [==============================] - 7s 817ms/step - loss: 0.1012 - accuracy: 0.9586 - val_loss: 0.3579 - val_accuracy: 0.8654
# Epoch 28/30
# 8/8 [==============================] - 7s 819ms/step - loss: 0.1192 - accuracy: 0.9499 - val_loss: 0.1905 - val_accuracy: 0.9038
# Epoch 29/30
# 8/8 [==============================] - 7s 820ms/step - loss: 0.1123 - accuracy: 0.9564 - val_loss: 0.2819 - val_accuracy: 0.8846
# Epoch 30/30
# 8/8 [==============================] - 7s 804ms/step - loss: 0.1400 - accuracy: 0.9499 - val_loss: 0.1883 - val_accuracy: 0.9231

# %% [markdown]
# # **Evaluasi Model**

# %%
plt.plot(history.history["accuracy"], label="Akurasi Pelatihan")
plt.plot(history.history["val_accuracy"], label="Validasi Akurasi")
plt.legend()
plt.show()

plt.plot(history.history["loss"], label="Kesalahan Pelatihan")
plt.plot(history.history["val_loss"], label="Validasi Kesalahan")
plt.legend()
plt.show()

test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    dataframe=data_datatest,
    directory=None,  # Specify directory as None because full paths are provided in 'blurred_image'
    x_col='blurred_image',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)

predict = model.predict(test_generator, steps=np.ceil(nb_samples / batch_size))

predicted_classes = np.argmax(predict, axis=1)
true_classes = np.array(data_datatest['categories'].replace(['moi', 'nonmoi'], [0, 1]))
class_labels = ['0', '1']

cm = confusion_matrix(true_classes, predicted_classes)
cm_df = pd.DataFrame(cm, index=['moi', 'nonmoi'], columns=['moi', 'nonmoi'])

plt.figure(figsize=(8, 8))
sns.heatmap(cm_df, annot=True)
plt.title('CNN EfficientNet-B1 \nAccuracy:{0:.3f}'.format(accuracy_score(true_classes, predicted_classes)))
plt.ylabel('Label Sebenarnya')
plt.xlabel('Label Prediksi')
plt.show()

report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)

model.save('geeksforgeeks.h5')
# Out:
# Found 126 validated image filenames.
# 2/2 [==============================] - 7s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        90
#            1       1.00      0.61      0.76        36
#
#     accuracy                           0.89       126
#    macro avg       0.93      0.81      0.84       126
# weighted avg       0.90      0.89      0.88       126
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
