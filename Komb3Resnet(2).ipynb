# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Gaussian-Blur/blob/main/Komb3Resnet(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3
# !pip install PyWavelets
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from PyWavelets) (1.26.4)
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 35.2 MB/s eta 0:00:00
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
#from efficientnet.tfkeras import EfficientNetB0
#from tensorflow.keras.applications import VGG16
import matplotlib.pyplot as plt
import numpy as np
import pywt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
data_path = "/content/drive/MyDrive/modifdataset"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    #haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    #haar_image = cv2.resize(haar_image, (224, 224))

                    #Extract Haar + Gaussia
                    haar_image = apply_haar_wavelet_and_gaussian(image)

                    # Extract HOG features
                    hog_features = extract_hog_features(haar_image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(hog_features)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7cb4a98398ff> in <cell line: 2>()
#       1 # Load dataset
# ----> 2 data, labels = load_data(data_path)
#
# <ipython-input-19-730f6b006b5f> in load_data(path)
#      22
#      23                     # Extract HOG features
# ---> 24                     hog_features = extract_hog_features(haar_image)
#      25
#      26                     # Extract Gabor features
#
# <ipython-input-18-1bcd6e6903cb> in extract_hog_features(image)
#       2 def extract_hog_features(image):
#       3     if len(image.shape) == 3:
# ----> 4         image = rgb2gray(image)
#       5     features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
#       6     return features
#
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     436
#     437             if channel_axis is None:
# --> 438                 return func(*args, **kwargs)
#     439
#     440             # TODO: convert scalars to a tuple in anticipation of eventually
#
# /usr/local/lib/python3.10/dist-packages/skimage/color/colorconv.py in rgb2gray(rgb, channel_axis)
#     980     >>> img_gray = rgb2gray(img)
#     981     """
# --> 982     rgb = _prepare_colorarray(rgb)
#     983     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
#     984     return rgb @ coeffs
#
# /usr/local/lib/python3.10/dist-packages/skimage/color/colorconv.py in _prepare_colorarray(arr, force_copy, channel_axis)
#     168             f'got {arr.shape}'
#     169         )
# --> 170         raise ValueError(msg)
#     171
#     172     float_dtype = _supported_float_type(arr.dtype)
#
# ValueError: the input array must have size 3 along `channel_axis`, got (224, 112, 2)

# %%
num_images_to_display = 4  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3ac799b88fb0> in <cell line: 2>()
#       1 fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
#       2 for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
# ----> 3     axes[i].imshow(image.astype(np.uint8), cmap='gray')
#       4     axes[i].axis('off')
#       5     axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5749             self.set_aspect(aspect)
#    5750
# -> 5751         im.set_data(X)
#    5752         im.set_alpha(alpha)
#    5753         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in set_data(self, A)
#     721         if isinstance(A, PIL.Image.Image):
#     722             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723         self._A = self._normalize_image_array(A)
#     724         self._imcache = None
#     725         self.stale = True
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _normalize_image_array(A)
#     691             A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     692         if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 693             raise TypeError(f"Invalid shape {A.shape} for image data")
#     694         if A.ndim == 3:
#     695             # If the input data has values outside the valid range (after
#
# TypeError: Invalid shape (6084,) for image data

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    #rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.5,
    #zoom_range=0.5,
    #horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    #fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_and_preprocess_images(data_path)
test_images, test_labels = load_and_preprocess_images(data_path)

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.1988 - loss: 16.2323 - val_accuracy: 0.1952 - val_loss: 14.8117 - learning_rate: 1.0000e-04
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 408ms/step - accuracy: 0.2115 - loss: 15.6185 - val_accuracy: 0.2489 - val_loss: 14.5804 - learning_rate: 1.0000e-04
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 407ms/step - accuracy: 0.2279 - loss: 15.1302 - val_accuracy: 0.2417 - val_loss: 14.4139 - learning_rate: 1.0000e-04
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.2158 - loss: 14.8468 - val_accuracy: 0.2489 - val_loss: 14.2468 - learning_rate: 1.0000e-04
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.2285 - loss: 14.5172 - val_accuracy: 0.2574 - val_loss: 14.0746 - learning_rate: 1.0000e-04
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.2181 - loss: 14.4354 - val_accuracy: 0.2528 - val_loss: 14.9153 - learning_rate: 1.0000e-04
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.2015 - loss: 14.2158 - val_accuracy: 0.2390 - val_loss: 14.3048 - learning_rate: 1.0000e-04
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.2002 - loss: 13.8857 - val_accuracy: 0.2069 - val_loss: 13.7754 - learning_rate: 1.0000e-04
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.2362 - loss: 13.7578 - val_accuracy: 0.1952 - val_loss: 13.3848 - learning_rate: 1.0000e-04
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.2097 - loss: 13.5133 - val_accuracy: 0.2187 - val_loss: 13.2931 - learning_rate: 1.0000e-04
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.2140 - loss: 13.3416 - val_accuracy: 0.2633 - val_loss: 12.9858 - learning_rate: 1.0000e-04
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.2470 - loss: 13.1066 - val_accuracy: 0.2698 - val_loss: 12.7876 - learning_rate: 1.0000e-04
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 414ms/step - accuracy: 0.2439 - loss: 12.8902 - val_accuracy: 0.3333 - val_loss: 12.5807 - learning_rate: 1.0000e-04
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 41s 414ms/step - accuracy: 0.2231 - loss: 12.7047 - val_accuracy: 0.3556 - val_loss: 12.3794 - learning_rate: 1.0000e-04
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.2489 - loss: 12.4675 - val_accuracy: 0.3536 - val_loss: 12.1769 - learning_rate: 1.0000e-04
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.2538 - loss: 12.2184 - val_accuracy: 0.3445 - val_loss: 11.9661 - learning_rate: 1.0000e-04
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.2442 - loss: 12.0171 - val_accuracy: 0.3287 - val_loss: 11.7552 - learning_rate: 1.0000e-04
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.2656 - loss: 11.8028 - val_accuracy: 0.3471 - val_loss: 11.5447 - learning_rate: 1.0000e-04
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.2764 - loss: 11.5560 - val_accuracy: 0.3851 - val_loss: 11.3275 - learning_rate: 1.0000e-04
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.2873 - loss: 11.3796 - val_accuracy: 0.3988 - val_loss: 11.1044 - learning_rate: 1.0000e-04
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.2942 - loss: 11.1290 - val_accuracy: 0.4257 - val_loss: 10.8710 - learning_rate: 1.0000e-04
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.3172 - loss: 10.8730 - val_accuracy: 0.4420 - val_loss: 10.6346 - learning_rate: 1.0000e-04
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.3275 - loss: 10.6889 - val_accuracy: 0.4047 - val_loss: 10.4234 - learning_rate: 1.0000e-04
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.3298 - loss: 10.4737 - val_accuracy: 0.4519 - val_loss: 10.1687 - learning_rate: 1.0000e-04
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.3846 - loss: 10.1911 - val_accuracy: 0.4623 - val_loss: 9.9416 - learning_rate: 1.0000e-04
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.3836 - loss: 9.9431 - val_accuracy: 0.4558 - val_loss: 9.6891 - learning_rate: 1.0000e-04
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.4343 - loss: 9.6518 - val_accuracy: 0.4957 - val_loss: 9.4036 - learning_rate: 1.0000e-04
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.4284 - loss: 9.4289 - val_accuracy: 0.3687 - val_loss: 9.5781 - learning_rate: 1.0000e-04
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.4555 - loss: 9.2274 - val_accuracy: 0.4198 - val_loss: 9.1528 - learning_rate: 1.0000e-04
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.4838 - loss: 8.9498 - val_accuracy: 0.4172 - val_loss: 9.0282 - learning_rate: 1.0000e-04
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.4958 - loss: 8.7147 - val_accuracy: 0.5796 - val_loss: 8.5320 - learning_rate: 1.0000e-04
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.5095 - loss: 8.4656 - val_accuracy: 0.5344 - val_loss: 8.3214 - learning_rate: 1.0000e-04
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.5164 - loss: 8.2905 - val_accuracy: 0.5193 - val_loss: 8.1458 - learning_rate: 1.0000e-04
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.5379 - loss: 8.0720 - val_accuracy: 0.5200 - val_loss: 7.9544 - learning_rate: 1.0000e-04
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.5032 - loss: 7.9175 - val_accuracy: 0.5619 - val_loss: 7.7743 - learning_rate: 1.0000e-04
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.5977 - loss: 7.5996 - val_accuracy: 0.5213 - val_loss: 7.6765 - learning_rate: 1.0000e-04
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.5908 - loss: 7.4140 - val_accuracy: 0.5783 - val_loss: 7.3426 - learning_rate: 1.0000e-04
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.6197 - loss: 7.1279 - val_accuracy: 0.6909 - val_loss: 6.9232 - learning_rate: 1.0000e-04
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.6240 - loss: 6.9683 - val_accuracy: 0.4453 - val_loss: 7.6360 - learning_rate: 1.0000e-04
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.6372 - loss: 6.8072 - val_accuracy: 0.7367 - val_loss: 6.4285 - learning_rate: 1.0000e-04
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.6289 - loss: 6.5880 - val_accuracy: 0.6863 - val_loss: 6.3990 - learning_rate: 1.0000e-04
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.6404 - loss: 6.3810 - val_accuracy: 0.6313 - val_loss: 7.7864 - learning_rate: 1.0000e-04
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 408ms/step - accuracy: 0.6682 - loss: 6.1448 - val_accuracy: 0.6221 - val_loss: 6.4398 - learning_rate: 1.0000e-04
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.7091 - loss: 5.9661 - val_accuracy: 0.6857 - val_loss: 5.9588 - learning_rate: 1.0000e-04
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.7094 - loss: 5.8077 - val_accuracy: 0.7636 - val_loss: 5.6304 - learning_rate: 1.0000e-04
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.7263 - loss: 5.6312 - val_accuracy: 0.8212 - val_loss: 5.2588 - learning_rate: 1.0000e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 407ms/step - accuracy: 0.7420 - loss: 5.4151 - val_accuracy: 0.7171 - val_loss: 5.4841 - learning_rate: 1.0000e-04
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.7244 - loss: 5.2910 - val_accuracy: 0.8245 - val_loss: 5.0132 - learning_rate: 1.0000e-04
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.7632 - loss: 5.0863 - val_accuracy: 0.6221 - val_loss: 5.3855 - learning_rate: 1.0000e-04
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.7751 - loss: 4.9117 - val_accuracy: 0.7263 - val_loss: 5.0239 - learning_rate: 1.0000e-04
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.7693 - loss: 4.8097 - val_accuracy: 0.6477 - val_loss: 5.0487 - learning_rate: 1.0000e-04
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 416ms/step - accuracy: 0.7713 - loss: 4.6771 - val_accuracy: 0.7721 - val_loss: 4.5682 - learning_rate: 1.0000e-04
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.7967 - loss: 4.4583 - val_accuracy: 0.6241 - val_loss: 5.0684 - learning_rate: 1.0000e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.8525 - loss: 4.2485 - val_accuracy: 0.6248 - val_loss: 4.8647 - learning_rate: 1.0000e-04
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.8318 - loss: 4.2108 - val_accuracy: 0.8566 - val_loss: 4.0276 - learning_rate: 1.0000e-04
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.8816 - loss: 3.9460 - val_accuracy: 0.8775 - val_loss: 3.8700 - learning_rate: 1.0000e-04
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 414ms/step - accuracy: 0.8633 - loss: 3.8794 - val_accuracy: 0.8952 - val_loss: 3.6977 - learning_rate: 1.0000e-04
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 406ms/step - accuracy: 0.8619 - loss: 3.7577 - val_accuracy: 0.8088 - val_loss: 3.8501 - learning_rate: 1.0000e-04
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.8889 - loss: 3.5672 - val_accuracy: 0.8134 - val_loss: 3.7561 - learning_rate: 1.0000e-04
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 414ms/step - accuracy: 0.8969 - loss: 3.4669 - val_accuracy: 0.9208 - val_loss: 3.3049 - learning_rate: 1.0000e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9140 - loss: 3.3134 - val_accuracy: 0.9411 - val_loss: 3.1368 - learning_rate: 1.0000e-04
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9150 - loss: 3.2085 - val_accuracy: 0.9561 - val_loss: 2.9896 - learning_rate: 1.0000e-04
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9374 - loss: 3.0504 - val_accuracy: 0.8546 - val_loss: 3.1366 - learning_rate: 1.0000e-04
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9346 - loss: 2.9635 - val_accuracy: 0.8350 - val_loss: 3.2131 - learning_rate: 1.0000e-04
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9332 - loss: 2.8862 - val_accuracy: 0.8644 - val_loss: 3.0137 - learning_rate: 1.0000e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.9291 - loss: 2.7830 - val_accuracy: 0.8690 - val_loss: 2.8796 - learning_rate: 1.0000e-04
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 416ms/step - accuracy: 0.9276 - loss: 2.6785 - val_accuracy: 0.9070 - val_loss: 2.7050 - learning_rate: 1.0000e-04
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 414ms/step - accuracy: 0.9480 - loss: 2.5769 - val_accuracy: 0.9391 - val_loss: 2.4824 - learning_rate: 1.0000e-04
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 408ms/step - accuracy: 0.9460 - loss: 2.4691 - val_accuracy: 0.8088 - val_loss: 2.8766 - learning_rate: 1.0000e-04
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 414ms/step - accuracy: 0.9461 - loss: 2.3520 - val_accuracy: 0.9260 - val_loss: 2.3731 - learning_rate: 1.0000e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9524 - loss: 2.2806 - val_accuracy: 0.8500 - val_loss: 2.5224 - learning_rate: 1.0000e-04
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9381 - loss: 2.2491 - val_accuracy: 0.8644 - val_loss: 2.3812 - learning_rate: 1.0000e-04
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.9617 - loss: 2.0870 - val_accuracy: 0.9561 - val_loss: 2.0479 - learning_rate: 1.0000e-04
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9592 - loss: 2.0469 - val_accuracy: 0.9005 - val_loss: 2.1228 - learning_rate: 1.0000e-04
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9533 - loss: 1.9855 - val_accuracy: 0.8232 - val_loss: 2.3129 - learning_rate: 1.0000e-04
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9703 - loss: 1.8502 - val_accuracy: 0.9764 - val_loss: 1.7572 - learning_rate: 1.0000e-04
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9744 - loss: 1.7973 - val_accuracy: 0.9404 - val_loss: 1.8205 - learning_rate: 1.0000e-04
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9639 - loss: 1.7470 - val_accuracy: 0.8291 - val_loss: 2.1714 - learning_rate: 1.0000e-04
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9470 - loss: 1.6956 - val_accuracy: 0.8900 - val_loss: 1.8904 - learning_rate: 1.0000e-04
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9750 - loss: 1.5978 - val_accuracy: 0.9037 - val_loss: 1.7532 - learning_rate: 1.0000e-04
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9677 - loss: 1.5374 - val_accuracy: 0.9443 - val_loss: 1.5353 - learning_rate: 1.0000e-04
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9730 - loss: 1.4629 - val_accuracy: 0.9745 - val_loss: 1.4088 - learning_rate: 1.0000e-04
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9735 - loss: 1.3984 - val_accuracy: 0.9745 - val_loss: 1.3389 - learning_rate: 1.0000e-04
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9745 - loss: 1.3425 - val_accuracy: 0.9299 - val_loss: 1.4399 - learning_rate: 1.0000e-04
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 406ms/step - accuracy: 0.9590 - loss: 1.3736 - val_accuracy: 0.7629 - val_loss: 1.9737 - learning_rate: 1.0000e-04
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.9804 - loss: 1.2293 - val_accuracy: 0.9659 - val_loss: 1.2277 - learning_rate: 1.0000e-04
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 409ms/step - accuracy: 0.9804 - loss: 1.1849 - val_accuracy: 0.9378 - val_loss: 1.2768 - learning_rate: 1.0000e-04
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.9724 - loss: 1.1460 - val_accuracy: 0.9384 - val_loss: 1.2340 - learning_rate: 1.0000e-04
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9619 - loss: 1.1319 - val_accuracy: 0.9849 - val_loss: 1.0172 - learning_rate: 1.0000e-04
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 410ms/step - accuracy: 0.9819 - loss: 1.0393 - val_accuracy: 0.9476 - val_loss: 1.0958 - learning_rate: 1.0000e-04
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 417ms/step - accuracy: 0.9583 - loss: 1.0711 - val_accuracy: 0.9627 - val_loss: 1.0021 - learning_rate: 1.0000e-04
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.9838 - loss: 0.9581 - val_accuracy: 0.9620 - val_loss: 0.9894 - learning_rate: 1.0000e-04
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9660 - loss: 0.9811 - val_accuracy: 0.9352 - val_loss: 0.9980 - learning_rate: 1.0000e-04
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 414ms/step - accuracy: 0.9741 - loss: 0.8922 - val_accuracy: 0.9614 - val_loss: 0.8983 - learning_rate: 1.0000e-04
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9620 - loss: 0.8940 - val_accuracy: 0.9836 - val_loss: 0.8076 - learning_rate: 1.0000e-04
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9783 - loss: 0.8142 - val_accuracy: 0.9882 - val_loss: 0.7653 - learning_rate: 1.0000e-04
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9752 - loss: 0.7813 - val_accuracy: 0.9666 - val_loss: 0.7928 - learning_rate: 1.0000e-04
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9626 - loss: 0.8409 - val_accuracy: 0.9915 - val_loss: 0.6854 - learning_rate: 1.0000e-04
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9831 - loss: 0.7209 - val_accuracy: 0.9587 - val_loss: 0.7684 - learning_rate: 1.0000e-04
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9822 - loss: 0.6987 - val_accuracy: 0.9758 - val_loss: 0.6860 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step
#               precision    recall  f1-score   support
#
#      Aitinyo       1.00      0.97      0.99       374
#      Ayamaru       0.98      1.00      0.99       311
#       Kokoda       1.00      1.00      1.00       302
#          Moi       1.00      0.99      1.00       301
#        Tehit       0.98      1.00      0.99       239
#
#     accuracy                           0.99      1527
#    macro avg       0.99      0.99      0.99      1527
# weighted avg       0.99      0.99      0.99      1527

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
import pywt
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Paths
data_path = "/content/drive/MyDrive/modifdataset"  # Path to dataset

# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Apply histogram equalization and noise reduction
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB for compatibility with CNN models
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# Function to extract HOG and Haar Wavelet features
def extract_combined_features(image):
    # Convert to grayscale if necessary
    if len(image.shape) == 3:
        image = rgb2gray(image)
    # Extract HOG features
    hog_features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    # Apply Haar Wavelet transformation and Gaussian filter
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)
    # Flatten Haar features
    haar_features = LL_gaussian.flatten()
    # Combine features
    return np.concatenate([hog_features, haar_features])

# Load dataset and preprocess
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess and extract combined features
                    image = preprocess_image(image)
                    combined_features = extract_combined_features(image)
                    data.append(combined_features)
                    labels.append(folder)
    return np.array(data), np.array(labels)

# Load dataset
data, labels = load_data(data_path)

# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# Split into training and testing
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

# Calculate class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.5,
    zoom_range=0.5,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2]
)
test_datagen = ImageDataGenerator()

# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

train_images, train_labels = load_and_preprocess_images(data_path)
test_images, test_labels = load_and_preprocess_images(data_path)

# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)

# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.2173 - loss: 16.2569 - val_accuracy: 0.2331 - val_loss: 14.8917 - learning_rate: 1.0000e-04
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.1873 - loss: 15.7278 - val_accuracy: 0.2489 - val_loss: 14.6959 - learning_rate: 1.0000e-04
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.2003 - loss: 15.3333 - val_accuracy: 0.2443 - val_loss: 14.4141 - learning_rate: 1.0000e-04
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 433ms/step - accuracy: 0.2056 - loss: 14.9517 - val_accuracy: 0.2286 - val_loss: 14.3027 - learning_rate: 1.0000e-04
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.2153 - loss: 14.6072 - val_accuracy: 0.2430 - val_loss: 14.1346 - learning_rate: 1.0000e-04
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 429ms/step - accuracy: 0.1951 - loss: 14.4214 - val_accuracy: 0.2299 - val_loss: 13.9368 - learning_rate: 1.0000e-04
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.2247 - loss: 14.1517 - val_accuracy: 0.2475 - val_loss: 13.7495 - learning_rate: 1.0000e-04
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 433ms/step - accuracy: 0.1936 - loss: 13.9401 - val_accuracy: 0.2115 - val_loss: 13.5460 - learning_rate: 1.0000e-04
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.2368 - loss: 13.7134 - val_accuracy: 0.2469 - val_loss: 13.3154 - learning_rate: 1.0000e-04
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 435ms/step - accuracy: 0.2220 - loss: 13.4995 - val_accuracy: 0.2456 - val_loss: 13.1308 - learning_rate: 1.0000e-04
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 435ms/step - accuracy: 0.2603 - loss: 13.2430 - val_accuracy: 0.2809 - val_loss: 12.9264 - learning_rate: 1.0000e-04
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.2326 - loss: 13.0579 - val_accuracy: 0.2567 - val_loss: 12.7422 - learning_rate: 1.0000e-04
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.2133 - loss: 12.8779 - val_accuracy: 0.2803 - val_loss: 12.5683 - learning_rate: 1.0000e-04
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 435ms/step - accuracy: 0.2279 - loss: 12.6457 - val_accuracy: 0.2489 - val_loss: 12.3873 - learning_rate: 1.0000e-04
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 433ms/step - accuracy: 0.1913 - loss: 12.4879 - val_accuracy: 0.2325 - val_loss: 12.1692 - learning_rate: 1.0000e-04
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.2326 - loss: 12.2081 - val_accuracy: 0.3137 - val_loss: 11.9474 - learning_rate: 1.0000e-04
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 437ms/step - accuracy: 0.2409 - loss: 11.9720 - val_accuracy: 0.3268 - val_loss: 11.7411 - learning_rate: 1.0000e-04
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 431ms/step - accuracy: 0.2544 - loss: 11.8118 - val_accuracy: 0.3091 - val_loss: 11.5546 - learning_rate: 1.0000e-04
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.2526 - loss: 11.6161 - val_accuracy: 0.3006 - val_loss: 11.3489 - learning_rate: 1.0000e-04
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.2551 - loss: 11.3827 - val_accuracy: 0.3006 - val_loss: 11.1454 - learning_rate: 1.0000e-04
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 432ms/step - accuracy: 0.2450 - loss: 11.1857 - val_accuracy: 0.3425 - val_loss: 10.8999 - learning_rate: 1.0000e-04
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 439ms/step - accuracy: 0.2731 - loss: 10.9558 - val_accuracy: 0.3563 - val_loss: 10.6956 - learning_rate: 1.0000e-04
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 432ms/step - accuracy: 0.2642 - loss: 10.7502 - val_accuracy: 0.3222 - val_loss: 10.5061 - learning_rate: 1.0000e-04
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.2573 - loss: 10.5851 - val_accuracy: 0.3477 - val_loss: 10.2920 - learning_rate: 1.0000e-04
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.2627 - loss: 10.3162 - val_accuracy: 0.2567 - val_loss: 10.2354 - learning_rate: 1.0000e-04
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.2487 - loss: 10.1561 - val_accuracy: 0.3739 - val_loss: 9.8589 - learning_rate: 1.0000e-04
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.2606 - loss: 9.9398 - val_accuracy: 0.3563 - val_loss: 9.6471 - learning_rate: 1.0000e-04
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.2798 - loss: 9.7445 - val_accuracy: 0.3818 - val_loss: 9.4589 - learning_rate: 1.0000e-04
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 432ms/step - accuracy: 0.2902 - loss: 9.5300 - val_accuracy: 0.3798 - val_loss: 9.2524 - learning_rate: 1.0000e-04
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.2450 - loss: 9.3808 - val_accuracy: 0.3890 - val_loss: 9.0327 - learning_rate: 1.0000e-04
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.3043 - loss: 9.1083 - val_accuracy: 0.4113 - val_loss: 8.8683 - learning_rate: 1.0000e-04
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.3135 - loss: 8.9370 - val_accuracy: 0.4420 - val_loss: 8.6354 - learning_rate: 1.0000e-04
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.3233 - loss: 8.7101 - val_accuracy: 0.3176 - val_loss: 8.5214 - learning_rate: 1.0000e-04
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.3364 - loss: 8.4905 - val_accuracy: 0.3877 - val_loss: 8.2796 - learning_rate: 1.0000e-04
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.3713 - loss: 8.2748 - val_accuracy: 0.3674 - val_loss: 8.1807 - learning_rate: 1.0000e-04
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.3515 - loss: 8.1147 - val_accuracy: 0.4113 - val_loss: 7.9016 - learning_rate: 1.0000e-04
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.3455 - loss: 7.9594 - val_accuracy: 0.4283 - val_loss: 7.6781 - learning_rate: 1.0000e-04
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.3716 - loss: 7.7314 - val_accuracy: 0.4335 - val_loss: 7.4601 - learning_rate: 1.0000e-04
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.3847 - loss: 7.5138 - val_accuracy: 0.4276 - val_loss: 7.2882 - learning_rate: 1.0000e-04
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.3656 - loss: 7.3820 - val_accuracy: 0.4479 - val_loss: 7.1342 - learning_rate: 1.0000e-04
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.3737 - loss: 7.2069 - val_accuracy: 0.3982 - val_loss: 7.0360 - learning_rate: 1.0000e-04
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.3957 - loss: 7.0289 - val_accuracy: 0.3589 - val_loss: 6.9692 - learning_rate: 1.0000e-04
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.3865 - loss: 6.8351 - val_accuracy: 0.4872 - val_loss: 6.5640 - learning_rate: 1.0000e-04
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.3861 - loss: 6.6684 - val_accuracy: 0.4375 - val_loss: 6.5487 - learning_rate: 1.0000e-04
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.3918 - loss: 6.5648 - val_accuracy: 0.4741 - val_loss: 6.2736 - learning_rate: 1.0000e-04
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.4110 - loss: 6.3209 - val_accuracy: 0.4303 - val_loss: 6.2003 - learning_rate: 1.0000e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.4379 - loss: 6.1180 - val_accuracy: 0.5154 - val_loss: 5.8607 - learning_rate: 1.0000e-04
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.4236 - loss: 6.0060 - val_accuracy: 0.4558 - val_loss: 5.8619 - learning_rate: 1.0000e-04
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.4412 - loss: 5.8490 - val_accuracy: 0.4833 - val_loss: 5.6602 - learning_rate: 1.0000e-04
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.4613 - loss: 5.6472 - val_accuracy: 0.4401 - val_loss: 5.5782 - learning_rate: 1.0000e-04
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.4318 - loss: 5.5564 - val_accuracy: 0.4833 - val_loss: 5.3113 - learning_rate: 1.0000e-04
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.4448 - loss: 5.3990 - val_accuracy: 0.5573 - val_loss: 5.1275 - learning_rate: 1.0000e-04
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.4669 - loss: 5.2498 - val_accuracy: 0.5422 - val_loss: 4.9788 - learning_rate: 1.0000e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.4737 - loss: 5.0992 - val_accuracy: 0.4532 - val_loss: 5.0875 - learning_rate: 1.0000e-04
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.4504 - loss: 4.9760 - val_accuracy: 0.5213 - val_loss: 4.7561 - learning_rate: 1.0000e-04
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.4878 - loss: 4.7976 - val_accuracy: 0.5455 - val_loss: 4.5769 - learning_rate: 1.0000e-04
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.4617 - loss: 4.7477 - val_accuracy: 0.5075 - val_loss: 4.5297 - learning_rate: 1.0000e-04
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.4834 - loss: 4.6028 - val_accuracy: 0.5213 - val_loss: 4.4195 - learning_rate: 1.0000e-04
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.4850 - loss: 4.4433 - val_accuracy: 0.5717 - val_loss: 4.1953 - learning_rate: 1.0000e-04
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.5011 - loss: 4.3188 - val_accuracy: 0.5265 - val_loss: 4.1337 - learning_rate: 1.0000e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.5112 - loss: 4.1817 - val_accuracy: 0.6221 - val_loss: 3.8711 - learning_rate: 1.0000e-04
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.5139 - loss: 4.0650 - val_accuracy: 0.5796 - val_loss: 3.7936 - learning_rate: 1.0000e-04
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.5083 - loss: 3.9754 - val_accuracy: 0.5363 - val_loss: 3.8395 - learning_rate: 1.0000e-04
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.5085 - loss: 3.8592 - val_accuracy: 0.5842 - val_loss: 3.6092 - learning_rate: 1.0000e-04
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.5195 - loss: 3.7553 - val_accuracy: 0.5180 - val_loss: 3.6979 - learning_rate: 1.0000e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.5254 - loss: 3.6661 - val_accuracy: 0.5684 - val_loss: 3.4621 - learning_rate: 1.0000e-04
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.5357 - loss: 3.5379 - val_accuracy: 0.5475 - val_loss: 3.4030 - learning_rate: 1.0000e-04
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.5605 - loss: 3.4479 - val_accuracy: 0.5789 - val_loss: 3.2538 - learning_rate: 1.0000e-04
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.5309 - loss: 3.3271 - val_accuracy: 0.5763 - val_loss: 3.1949 - learning_rate: 1.0000e-04
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 436ms/step - accuracy: 0.5222 - loss: 3.2885 - val_accuracy: 0.6136 - val_loss: 3.0273 - learning_rate: 1.0000e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 437ms/step - accuracy: 0.5688 - loss: 3.1290 - val_accuracy: 0.5573 - val_loss: 3.1968 - learning_rate: 1.0000e-04
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 433ms/step - accuracy: 0.5663 - loss: 3.0535 - val_accuracy: 0.5992 - val_loss: 2.9599 - learning_rate: 1.0000e-04
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.5559 - loss: 2.9872 - val_accuracy: 0.6732 - val_loss: 2.6319 - learning_rate: 1.0000e-04
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 429ms/step - accuracy: 0.5713 - loss: 2.8861 - val_accuracy: 0.6457 - val_loss: 2.6630 - learning_rate: 1.0000e-04
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.5849 - loss: 2.7790 - val_accuracy: 0.5920 - val_loss: 2.7940 - learning_rate: 1.0000e-04
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.5846 - loss: 2.7135 - val_accuracy: 0.5900 - val_loss: 2.6996 - learning_rate: 1.0000e-04
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.6078 - loss: 2.6044 - val_accuracy: 0.4283 - val_loss: 3.7131 - learning_rate: 1.0000e-04
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.5731 - loss: 2.5795 - val_accuracy: 0.6804 - val_loss: 2.3676 - learning_rate: 1.0000e-04
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.6147 - loss: 2.4759 - val_accuracy: 0.6647 - val_loss: 2.3349 - learning_rate: 1.0000e-04
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.6629 - loss: 2.3717 - val_accuracy: 0.6942 - val_loss: 2.1776 - learning_rate: 1.0000e-04
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 432ms/step - accuracy: 0.6393 - loss: 2.3224 - val_accuracy: 0.7073 - val_loss: 2.1122 - learning_rate: 1.0000e-04
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.6488 - loss: 2.2674 - val_accuracy: 0.5979 - val_loss: 2.3329 - learning_rate: 1.0000e-04
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.6122 - loss: 2.2514 - val_accuracy: 0.6824 - val_loss: 2.0613 - learning_rate: 1.0000e-04
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.6566 - loss: 2.1343 - val_accuracy: 0.7453 - val_loss: 1.8721 - learning_rate: 1.0000e-04
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.6689 - loss: 2.1084 - val_accuracy: 0.6948 - val_loss: 1.9493 - learning_rate: 1.0000e-04
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.6501 - loss: 2.0565 - val_accuracy: 0.6149 - val_loss: 2.2661 - learning_rate: 1.0000e-04
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.6443 - loss: 2.0459 - val_accuracy: 0.7885 - val_loss: 1.6474 - learning_rate: 1.0000e-04
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.6494 - loss: 1.9272 - val_accuracy: 0.6031 - val_loss: 2.0622 - learning_rate: 1.0000e-04
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.6553 - loss: 1.9003 - val_accuracy: 0.5435 - val_loss: 2.4782 - learning_rate: 1.0000e-04
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.7033 - loss: 1.7712 - val_accuracy: 0.7328 - val_loss: 1.7485 - learning_rate: 1.0000e-04
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.6805 - loss: 1.7888 - val_accuracy: 0.7328 - val_loss: 1.6561 - learning_rate: 1.0000e-04
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.6715 - loss: 1.7449 - val_accuracy: 0.7420 - val_loss: 1.5562 - learning_rate: 1.0000e-04
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.7044 - loss: 1.6730 - val_accuracy: 0.7315 - val_loss: 1.5813 - learning_rate: 1.0000e-04
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.6860 - loss: 1.6537 - val_accuracy: 0.7911 - val_loss: 1.4058 - learning_rate: 1.0000e-04
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.7055 - loss: 1.6095 - val_accuracy: 0.6470 - val_loss: 1.8667 - learning_rate: 1.0000e-04
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.7228 - loss: 1.5325 - val_accuracy: 0.7282 - val_loss: 1.4491 - learning_rate: 1.0000e-04
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.7226 - loss: 1.5143 - val_accuracy: 0.7466 - val_loss: 1.3874 - learning_rate: 1.0000e-04
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.7027 - loss: 1.5116 - val_accuracy: 0.7904 - val_loss: 1.2541 - learning_rate: 1.0000e-04
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.7215 - loss: 1.4235 - val_accuracy: 0.7119 - val_loss: 1.5774 - learning_rate: 1.0000e-04
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 429ms/step - accuracy: 0.7249 - loss: 1.4239 - val_accuracy: 0.7590 - val_loss: 1.3058 - learning_rate: 1.0000e-04
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step
#               precision    recall  f1-score   support
#
#      Aitinyo       0.86      0.49      0.63       374
#      Ayamaru       0.59      0.89      0.71       311
#       Kokoda       0.88      0.99      0.93       302
#          Moi       0.89      0.82      0.85       301
#        Tehit       0.89      0.82      0.85       239
#
#     accuracy                           0.79      1527
#    macro avg       0.82      0.81      0.80      1527
# weighted avg       0.82      0.79      0.79      1527

# %% [markdown]
# # **PERCOBAAN LAGI**

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
#from efficientnet.tfkeras import EfficientNetB0
#from tensorflow.keras.applications import VGG16
import matplotlib.pyplot as plt
import numpy as np
import pywt

# %%
# Paths
data_path = "/content/drive/MyDrive/modifdataset"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    #haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    #haar_image = cv2.resize(haar_image, (224, 224))

                    #Extract Haar + Gaussia
                    haar_image = apply_haar_wavelet_and_gaussian(image)

                    # Extract HOG features
                    hog_features = extract_hog_features(haar_image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(hog_features)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-7cb4a98398ff> in <cell line: 2>()
#       1 # Load dataset
# ----> 2 data, labels = load_data(data_path)
#
# <ipython-input-35-eb0db07deae4> in load_data(path)
#      22
#      23                     # Extract HOG features
# ---> 24                     hog_features = extract_hog_features(haar_image)
#      25
#      26                     # Extract Gabor features
#
# <ipython-input-28-1bcd6e6903cb> in extract_hog_features(image)
#       2 def extract_hog_features(image):
#       3     if len(image.shape) == 3:
# ----> 4         image = rgb2gray(image)
#       5     features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
#       6     return features
#
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     436
#     437             if channel_axis is None:
# --> 438                 return func(*args, **kwargs)
#     439
#     440             # TODO: convert scalars to a tuple in anticipation of eventually
#
# /usr/local/lib/python3.10/dist-packages/skimage/color/colorconv.py in rgb2gray(rgb, channel_axis)
#     980     >>> img_gray = rgb2gray(img)
#     981     """
# --> 982     rgb = _prepare_colorarray(rgb)
#     983     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
#     984     return rgb @ coeffs
#
# /usr/local/lib/python3.10/dist-packages/skimage/color/colorconv.py in _prepare_colorarray(arr, force_copy, channel_axis)
#     168             f'got {arr.shape}'
#     169         )
# --> 170         raise ValueError(msg)
#     171
#     172     float_dtype = _supported_float_type(arr.dtype)
#
# ValueError: the input array must have size 3 along `channel_axis`, got (224, 112, 2)

# %%
num_images_to_display = 4  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-3ac799b88fb0> in <cell line: 2>()
#       1 fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
#       2 for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
# ----> 3     axes[i].imshow(image.astype(np.uint8), cmap='gray')
#       4     axes[i].axis('off')
#       5     axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5749             self.set_aspect(aspect)
#    5750
# -> 5751         im.set_data(X)
#    5752         im.set_alpha(alpha)
#    5753         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in set_data(self, A)
#     721         if isinstance(A, PIL.Image.Image):
#     722             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723         self._A = self._normalize_image_array(A)
#     724         self._imcache = None
#     725         self.stale = True
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _normalize_image_array(A)
#     691             A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     692         if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 693             raise TypeError(f"Invalid shape {A.shape} for image data")
#     694         if A.ndim == 3:
#     695             # If the input data has values outside the valid range (after
#
# TypeError: Invalid shape (38788,) for image data

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    #rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.5,
    #zoom_range=0.5,
    #horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    #fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_and_preprocess_images(data_path)
test_images, test_labels = load_and_preprocess_images(data_path)

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.2034 - loss: 16.1808 - val_accuracy: 0.2508 - val_loss: 14.8101 - learning_rate: 1.0000e-04
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.2376 - loss: 15.4888 - val_accuracy: 0.2364 - val_loss: 14.5757 - learning_rate: 1.0000e-04
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.2286 - loss: 15.1229 - val_accuracy: 0.2600 - val_loss: 14.4001 - learning_rate: 1.0000e-04
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.2277 - loss: 14.8262 - val_accuracy: 0.2823 - val_loss: 14.2077 - learning_rate: 1.0000e-04
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.2246 - loss: 14.6343 - val_accuracy: 0.2475 - val_loss: 14.0538 - learning_rate: 1.0000e-04
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.2481 - loss: 14.3304 - val_accuracy: 0.2836 - val_loss: 13.8445 - learning_rate: 1.0000e-04
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 432ms/step - accuracy: 0.2348 - loss: 14.1653 - val_accuracy: 0.2764 - val_loss: 13.7080 - learning_rate: 1.0000e-04
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.2378 - loss: 13.8954 - val_accuracy: 0.3091 - val_loss: 13.5376 - learning_rate: 1.0000e-04
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.2844 - loss: 13.6416 - val_accuracy: 0.3635 - val_loss: 13.2532 - learning_rate: 1.0000e-04
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.2808 - loss: 13.3885 - val_accuracy: 0.3366 - val_loss: 13.0894 - learning_rate: 1.0000e-04
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.2656 - loss: 13.2108 - val_accuracy: 0.3458 - val_loss: 12.8983 - learning_rate: 1.0000e-04
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.2914 - loss: 12.9592 - val_accuracy: 0.3124 - val_loss: 12.6615 - learning_rate: 1.0000e-04
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.2985 - loss: 12.7455 - val_accuracy: 0.3877 - val_loss: 12.4083 - learning_rate: 1.0000e-04
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.2972 - loss: 12.5198 - val_accuracy: 0.4191 - val_loss: 12.1861 - learning_rate: 1.0000e-04
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.3312 - loss: 12.2554 - val_accuracy: 0.3831 - val_loss: 11.9974 - learning_rate: 1.0000e-04
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.3702 - loss: 12.0199 - val_accuracy: 0.3883 - val_loss: 11.8521 - learning_rate: 1.0000e-04
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.3846 - loss: 11.7818 - val_accuracy: 0.4420 - val_loss: 11.4779 - learning_rate: 1.0000e-04
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.3891 - loss: 11.5606 - val_accuracy: 0.4794 - val_loss: 11.2251 - learning_rate: 1.0000e-04
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.4136 - loss: 11.2930 - val_accuracy: 0.4270 - val_loss: 11.1035 - learning_rate: 1.0000e-04
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.4333 - loss: 11.0751 - val_accuracy: 0.3995 - val_loss: 11.0660 - learning_rate: 1.0000e-04
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.4623 - loss: 10.8033 - val_accuracy: 0.5422 - val_loss: 10.5215 - learning_rate: 1.0000e-04
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.4842 - loss: 10.5554 - val_accuracy: 0.5056 - val_loss: 10.3364 - learning_rate: 1.0000e-04
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.5123 - loss: 10.2915 - val_accuracy: 0.5226 - val_loss: 10.3429 - learning_rate: 1.0000e-04
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.5412 - loss: 10.0560 - val_accuracy: 0.5593 - val_loss: 9.8284 - learning_rate: 1.0000e-04
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.5343 - loss: 9.8101 - val_accuracy: 0.5848 - val_loss: 9.5708 - learning_rate: 1.0000e-04
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.5881 - loss: 9.5444 - val_accuracy: 0.6614 - val_loss: 9.3382 - learning_rate: 1.0000e-04
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.5984 - loss: 9.3205 - val_accuracy: 0.7125 - val_loss: 8.9476 - learning_rate: 1.0000e-04
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.6164 - loss: 9.1011 - val_accuracy: 0.5999 - val_loss: 8.9911 - learning_rate: 1.0000e-04
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.5994 - loss: 8.9085 - val_accuracy: 0.6745 - val_loss: 8.6205 - learning_rate: 1.0000e-04
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.6404 - loss: 8.6651 - val_accuracy: 0.5527 - val_loss: 8.9409 - learning_rate: 1.0000e-04
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.6765 - loss: 8.3511 - val_accuracy: 0.7112 - val_loss: 8.2667 - learning_rate: 1.0000e-04
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.6972 - loss: 8.1257 - val_accuracy: 0.6549 - val_loss: 8.0641 - learning_rate: 1.0000e-04
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.7431 - loss: 7.8748 - val_accuracy: 0.7250 - val_loss: 7.7109 - learning_rate: 1.0000e-04
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.7573 - loss: 7.6861 - val_accuracy: 0.7380 - val_loss: 7.5937 - learning_rate: 1.0000e-04
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.7875 - loss: 7.4032 - val_accuracy: 0.7066 - val_loss: 7.4512 - learning_rate: 1.0000e-04
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 429ms/step - accuracy: 0.7952 - loss: 7.2266 - val_accuracy: 0.8494 - val_loss: 6.9517 - learning_rate: 1.0000e-04
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.7746 - loss: 7.0766 - val_accuracy: 0.6883 - val_loss: 7.2434 - learning_rate: 1.0000e-04
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.7966 - loss: 6.8471 - val_accuracy: 0.7623 - val_loss: 6.7475 - learning_rate: 1.0000e-04
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.8389 - loss: 6.5695 - val_accuracy: 0.7990 - val_loss: 6.4925 - learning_rate: 1.0000e-04
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.8421 - loss: 6.3735 - val_accuracy: 0.8854 - val_loss: 6.1220 - learning_rate: 1.0000e-04
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.8519 - loss: 6.1628 - val_accuracy: 0.8690 - val_loss: 5.9588 - learning_rate: 1.0000e-04
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.8678 - loss: 5.9666 - val_accuracy: 0.8212 - val_loss: 6.0744 - learning_rate: 1.0000e-04
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.8582 - loss: 5.8298 - val_accuracy: 0.8310 - val_loss: 5.7606 - learning_rate: 1.0000e-04
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.8715 - loss: 5.6110 - val_accuracy: 0.8016 - val_loss: 5.8098 - learning_rate: 1.0000e-04
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.8984 - loss: 5.3979 - val_accuracy: 0.9083 - val_loss: 5.2348 - learning_rate: 1.0000e-04
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9114 - loss: 5.2109 - val_accuracy: 0.8913 - val_loss: 5.1187 - learning_rate: 1.0000e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.9093 - loss: 5.0462 - val_accuracy: 0.6162 - val_loss: 5.9611 - learning_rate: 1.0000e-04
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.8984 - loss: 4.9570 - val_accuracy: 0.7426 - val_loss: 5.2756 - learning_rate: 1.0000e-04
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9301 - loss: 4.6667 - val_accuracy: 0.8376 - val_loss: 4.7905 - learning_rate: 1.0000e-04
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9374 - loss: 4.5083 - val_accuracy: 0.8579 - val_loss: 4.5957 - learning_rate: 1.0000e-04
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9209 - loss: 4.4052 - val_accuracy: 0.8376 - val_loss: 4.5747 - learning_rate: 1.0000e-04
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9223 - loss: 4.2918 - val_accuracy: 0.9430 - val_loss: 4.0530 - learning_rate: 1.0000e-04
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.9331 - loss: 4.0718 - val_accuracy: 0.8068 - val_loss: 4.3474 - learning_rate: 1.0000e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9361 - loss: 3.9417 - val_accuracy: 0.8572 - val_loss: 4.0583 - learning_rate: 1.0000e-04
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9508 - loss: 3.7399 - val_accuracy: 0.8566 - val_loss: 3.9701 - learning_rate: 1.0000e-04
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.9372 - loss: 3.6610 - val_accuracy: 0.7793 - val_loss: 4.0921 - learning_rate: 1.0000e-04
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.9340 - loss: 3.5428 - val_accuracy: 0.6536 - val_loss: 4.3952 - learning_rate: 1.0000e-04
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.9577 - loss: 3.3508 - val_accuracy: 0.9194 - val_loss: 3.3566 - learning_rate: 1.0000e-04
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9628 - loss: 3.2116 - val_accuracy: 0.9253 - val_loss: 3.2155 - learning_rate: 1.0000e-04
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9408 - loss: 3.1662 - val_accuracy: 0.8140 - val_loss: 3.4601 - learning_rate: 1.0000e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9569 - loss: 2.9803 - val_accuracy: 0.8703 - val_loss: 3.1388 - learning_rate: 1.0000e-04
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9587 - loss: 2.8643 - val_accuracy: 0.9155 - val_loss: 2.8875 - learning_rate: 1.0000e-04
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.9717 - loss: 2.7265 - val_accuracy: 0.8245 - val_loss: 3.1827 - learning_rate: 1.0000e-04
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.9709 - loss: 2.6356 - val_accuracy: 0.9633 - val_loss: 2.5406 - learning_rate: 1.0000e-04
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9445 - loss: 2.5611 - val_accuracy: 0.8127 - val_loss: 3.0762 - learning_rate: 1.0000e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9446 - loss: 2.4678 - val_accuracy: 0.9116 - val_loss: 2.5367 - learning_rate: 1.0000e-04
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.9587 - loss: 2.3505 - val_accuracy: 0.9659 - val_loss: 2.2341 - learning_rate: 1.0000e-04
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9713 - loss: 2.2112 - val_accuracy: 0.7996 - val_loss: 2.8529 - learning_rate: 1.0000e-04
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9642 - loss: 2.1478 - val_accuracy: 0.9548 - val_loss: 2.0788 - learning_rate: 1.0000e-04
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9640 - loss: 2.0556 - val_accuracy: 0.7243 - val_loss: 2.9251 - learning_rate: 1.0000e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 415ms/step - accuracy: 0.9540 - loss: 1.9949 - val_accuracy: 0.8147 - val_loss: 2.3999 - learning_rate: 1.0000e-04
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.9578 - loss: 1.9290 - val_accuracy: 0.9293 - val_loss: 1.9103 - learning_rate: 1.0000e-04
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.9541 - loss: 1.8444 - val_accuracy: 0.8638 - val_loss: 2.0475 - learning_rate: 1.0000e-04
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9685 - loss: 1.7285 - val_accuracy: 0.9745 - val_loss: 1.6283 - learning_rate: 1.0000e-04
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.9620 - loss: 1.6394 - val_accuracy: 0.9299 - val_loss: 1.6758 - learning_rate: 1.0000e-04
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 413ms/step - accuracy: 0.9596 - loss: 1.6157 - val_accuracy: 0.9234 - val_loss: 1.6433 - learning_rate: 1.0000e-04
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.9770 - loss: 1.4920 - val_accuracy: 0.9817 - val_loss: 1.4009 - learning_rate: 1.0000e-04
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.9701 - loss: 1.4103 - val_accuracy: 0.9162 - val_loss: 1.5354 - learning_rate: 1.0000e-04
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9661 - loss: 1.3849 - val_accuracy: 0.9614 - val_loss: 1.3323 - learning_rate: 1.0000e-04
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9813 - loss: 1.3089 - val_accuracy: 0.9627 - val_loss: 1.2849 - learning_rate: 1.0000e-04
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.9859 - loss: 1.2081 - val_accuracy: 0.9587 - val_loss: 1.2535 - learning_rate: 1.0000e-04
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.9823 - loss: 1.1675 - val_accuracy: 0.9882 - val_loss: 1.0916 - learning_rate: 1.0000e-04
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 413ms/step - accuracy: 0.9929 - loss: 1.0941 - val_accuracy: 0.9640 - val_loss: 1.1414 - learning_rate: 1.0000e-04
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9684 - loss: 1.1250 - val_accuracy: 0.9712 - val_loss: 1.0492 - learning_rate: 1.0000e-04
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.9811 - loss: 1.0443 - val_accuracy: 0.9646 - val_loss: 1.0188 - learning_rate: 1.0000e-04
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9623 - loss: 1.0265 - val_accuracy: 0.9777 - val_loss: 0.9415 - learning_rate: 1.0000e-04
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.9775 - loss: 0.9486 - val_accuracy: 0.8775 - val_loss: 1.2966 - learning_rate: 1.0000e-04
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.9550 - loss: 0.9686 - val_accuracy: 0.8415 - val_loss: 1.3760 - learning_rate: 1.0000e-04
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9582 - loss: 0.9097 - val_accuracy: 0.9725 - val_loss: 0.8347 - learning_rate: 1.0000e-04
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.9709 - loss: 0.8361 - val_accuracy: 0.7813 - val_loss: 1.4986 - learning_rate: 1.0000e-04
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9629 - loss: 0.8241 - val_accuracy: 0.9437 - val_loss: 0.8644 - learning_rate: 1.0000e-04
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9830 - loss: 0.7346 - val_accuracy: 0.9188 - val_loss: 0.9317 - learning_rate: 1.0000e-04
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9823 - loss: 0.7181 - val_accuracy: 0.9568 - val_loss: 0.7627 - learning_rate: 1.0000e-04
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.9644 - loss: 0.7245 - val_accuracy: 0.9817 - val_loss: 0.6344 - learning_rate: 1.0000e-04
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9610 - loss: 0.7275 - val_accuracy: 0.9823 - val_loss: 0.6274 - learning_rate: 1.0000e-04
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9825 - loss: 0.6345 - val_accuracy: 0.9745 - val_loss: 0.6359 - learning_rate: 1.0000e-04
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 411ms/step - accuracy: 0.9847 - loss: 0.5837 - val_accuracy: 0.9450 - val_loss: 0.6886 - learning_rate: 1.0000e-04
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.9763 - loss: 0.5870 - val_accuracy: 0.8402 - val_loss: 1.0874 - learning_rate: 1.0000e-04
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.9729 - loss: 0.5742 - val_accuracy: 0.8605 - val_loss: 0.9119 - learning_rate: 1.0000e-04
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 433ms/step - accuracy: 0.9784 - loss: 0.5369 - val_accuracy: 0.9483 - val_loss: 0.6165 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step
#               precision    recall  f1-score   support
#
#      Aitinyo       0.99      0.94      0.96       374
#      Ayamaru       0.98      0.97      0.97       311
#       Kokoda       1.00      0.99      0.99       302
#          Moi       0.83      1.00      0.91       301
#        Tehit       0.97      0.82      0.89       239
#
#     accuracy                           0.95      1527
#    macro avg       0.95      0.94      0.94      1527
# weighted avg       0.95      0.95      0.95      1527
