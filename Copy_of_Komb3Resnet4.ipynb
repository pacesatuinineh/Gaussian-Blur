# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Gaussian-Blur/blob/main/Copy_of_Komb3Resnet4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3
# !pip install PyWavelets
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from PyWavelets) (1.26.4)
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 73.4 MB/s eta 0:00:00
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
#from tensorflow.keras.applications import EfficientNetB0
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np
import pywt

import random
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
data_path = "/content/drive/MyDrive/modifdataset"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    #haar_image = apply_haar_wavelet(image)

                    #Resize the image to 224x224 for ResNet50
                    ##haar_image = apply_haar_wavelet_and_gaussian(haar_image)

                    # Extract HOG features
                    #hog_features = extract_hog_features(haar_image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)


                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    # 1. Gaussian Smoothing
                    gaussian_image = cv2.GaussianBlur(image, (5, 5), 0)

                    # 2. Haar Wavelet (Modified for 3 channels)
                    haar_image_LL = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,0]) #Channel R
                    haar_image_LH = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,1]) #Channel G
                    haar_image_HL = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,2]) #Channel B
                    haar_image = np.stack([haar_image_LL,haar_image_LH, haar_image_HL], axis=-1)
                    haar_image = cv2.resize(haar_image.astype(np.uint8), IMAGE_SIZE)

                    # 3. HOG Features (on the 3-channel Haar output)
                    hog_features = extract_hog_features(haar_image)

                    data.append(hog_features)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 4  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
#fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
#for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
#    axes[i].imshow(image.astype(np.uint8), cmap='gray')
#    axes[i].axis('off')
#    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
#plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    #rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.5,
    #zoom_range=0.5,
    #horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    #fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_and_preprocess_images(data_path)
test_images, test_labels = load_and_preprocess_images(data_path)

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.2040 - loss: 16.0692 - val_accuracy: 0.2174 - val_loss: 14.7709 - learning_rate: 1.0000e-04
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.2178 - loss: 15.4137 - val_accuracy: 0.2056 - val_loss: 14.6277 - learning_rate: 1.0000e-04
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.2023 - loss: 15.1549 - val_accuracy: 0.2541 - val_loss: 14.3989 - learning_rate: 1.0000e-04
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.2165 - loss: 14.8016 - val_accuracy: 0.2227 - val_loss: 14.2242 - learning_rate: 1.0000e-04
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 413ms/step - accuracy: 0.2540 - loss: 14.4377 - val_accuracy: 0.2358 - val_loss: 14.0158 - learning_rate: 1.0000e-04
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 413ms/step - accuracy: 0.2571 - loss: 14.2600 - val_accuracy: 0.3235 - val_loss: 13.7902 - learning_rate: 1.0000e-04
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.2603 - loss: 14.0074 - val_accuracy: 0.3143 - val_loss: 13.5923 - learning_rate: 1.0000e-04
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.2686 - loss: 13.7907 - val_accuracy: 0.2620 - val_loss: 13.4617 - learning_rate: 1.0000e-04
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.2693 - loss: 13.5109 - val_accuracy: 0.2777 - val_loss: 13.3968 - learning_rate: 1.0000e-04
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.2918 - loss: 13.2077 - val_accuracy: 0.3032 - val_loss: 13.0015 - learning_rate: 1.0000e-04
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.3189 - loss: 13.0056 - val_accuracy: 0.3078 - val_loss: 12.7655 - learning_rate: 1.0000e-04
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.3468 - loss: 12.7645 - val_accuracy: 0.3752 - val_loss: 12.4927 - learning_rate: 1.0000e-04
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.3380 - loss: 12.5212 - val_accuracy: 0.4041 - val_loss: 12.2276 - learning_rate: 1.0000e-04
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.3450 - loss: 12.3144 - val_accuracy: 0.3517 - val_loss: 12.0703 - learning_rate: 1.0000e-04
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.3967 - loss: 12.0469 - val_accuracy: 0.5213 - val_loss: 11.6624 - learning_rate: 1.0000e-04
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.4167 - loss: 11.7535 - val_accuracy: 0.4473 - val_loss: 11.5518 - learning_rate: 1.0000e-04
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.4575 - loss: 11.4969 - val_accuracy: 0.5534 - val_loss: 11.1672 - learning_rate: 1.0000e-04
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.4602 - loss: 11.2771 - val_accuracy: 0.5488 - val_loss: 10.9758 - learning_rate: 1.0000e-04
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.4767 - loss: 10.9797 - val_accuracy: 0.5724 - val_loss: 10.7658 - learning_rate: 1.0000e-04
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.5238 - loss: 10.7269 - val_accuracy: 0.5953 - val_loss: 10.4534 - learning_rate: 1.0000e-04
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.5553 - loss: 10.4569 - val_accuracy: 0.4650 - val_loss: 10.4884 - learning_rate: 1.0000e-04
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.5361 - loss: 10.2299 - val_accuracy: 0.5881 - val_loss: 10.0399 - learning_rate: 1.0000e-04
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.5825 - loss: 9.9431 - val_accuracy: 0.6117 - val_loss: 9.7626 - learning_rate: 1.0000e-04
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.5469 - loss: 9.8244 - val_accuracy: 0.6123 - val_loss: 9.5757 - learning_rate: 1.0000e-04
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.6085 - loss: 9.4965 - val_accuracy: 0.6771 - val_loss: 9.2208 - learning_rate: 1.0000e-04
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.6253 - loss: 9.2157 - val_accuracy: 0.7308 - val_loss: 8.8947 - learning_rate: 1.0000e-04
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.6571 - loss: 8.9876 - val_accuracy: 0.6863 - val_loss: 8.7957 - learning_rate: 1.0000e-04
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.6901 - loss: 8.7022 - val_accuracy: 0.7158 - val_loss: 8.5155 - learning_rate: 1.0000e-04
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.6937 - loss: 8.4896 - val_accuracy: 0.6143 - val_loss: 8.5709 - learning_rate: 1.0000e-04
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.7068 - loss: 8.2912 - val_accuracy: 0.7983 - val_loss: 7.9019 - learning_rate: 1.0000e-04
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.7600 - loss: 7.9517 - val_accuracy: 0.7950 - val_loss: 7.7168 - learning_rate: 1.0000e-04
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.7796 - loss: 7.7271 - val_accuracy: 0.6320 - val_loss: 7.8281 - learning_rate: 1.0000e-04
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.7840 - loss: 7.4896 - val_accuracy: 0.7865 - val_loss: 7.3659 - learning_rate: 1.0000e-04
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.7680 - loss: 7.3875 - val_accuracy: 0.7040 - val_loss: 7.3739 - learning_rate: 1.0000e-04
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.8064 - loss: 7.0580 - val_accuracy: 0.7217 - val_loss: 7.0632 - learning_rate: 1.0000e-04
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.8059 - loss: 6.8987 - val_accuracy: 0.7289 - val_loss: 6.8650 - learning_rate: 1.0000e-04
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.8340 - loss: 6.6472 - val_accuracy: 0.6385 - val_loss: 6.9630 - learning_rate: 1.0000e-04
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.8543 - loss: 6.3862 - val_accuracy: 0.6182 - val_loss: 6.8383 - learning_rate: 1.0000e-04
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.8374 - loss: 6.2170 - val_accuracy: 0.7577 - val_loss: 6.3263 - learning_rate: 1.0000e-04
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 416ms/step - accuracy: 0.8482 - loss: 6.0117 - val_accuracy: 0.5796 - val_loss: 6.7774 - learning_rate: 1.0000e-04
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.8699 - loss: 5.8183 - val_accuracy: 0.7669 - val_loss: 5.9652 - learning_rate: 1.0000e-04
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.8852 - loss: 5.5919 - val_accuracy: 0.8513 - val_loss: 5.5285 - learning_rate: 1.0000e-04
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 415ms/step - accuracy: 0.8797 - loss: 5.4649 - val_accuracy: 0.9273 - val_loss: 5.2059 - learning_rate: 1.0000e-04
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 414ms/step - accuracy: 0.8899 - loss: 5.2447 - val_accuracy: 0.7924 - val_loss: 5.3697 - learning_rate: 1.0000e-04
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.8935 - loss: 5.0905 - val_accuracy: 0.8703 - val_loss: 4.9682 - learning_rate: 1.0000e-04
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9224 - loss: 4.8359 - val_accuracy: 0.8114 - val_loss: 4.9814 - learning_rate: 1.0000e-04
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9215 - loss: 4.6789 - val_accuracy: 0.6752 - val_loss: 5.3085 - learning_rate: 1.0000e-04
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 419ms/step - accuracy: 0.9310 - loss: 4.4873 - val_accuracy: 0.8775 - val_loss: 4.5859 - learning_rate: 1.0000e-04
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.8935 - loss: 4.4779 - val_accuracy: 0.7308 - val_loss: 4.7905 - learning_rate: 1.0000e-04
# Epoch 50/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.9158 - loss: 4.2175 - val_accuracy: 0.9339 - val_loss: 4.0240 - learning_rate: 1.0000e-04
# Epoch 51/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.9344 - loss: 4.0023 - val_accuracy: 0.9090 - val_loss: 3.9788 - learning_rate: 1.0000e-04
# Epoch 52/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.9584 - loss: 3.8219 - val_accuracy: 0.8847 - val_loss: 3.9099 - learning_rate: 1.0000e-04
# Epoch 53/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 418ms/step - accuracy: 0.9282 - loss: 3.7510 - val_accuracy: 0.9116 - val_loss: 3.6661 - learning_rate: 1.0000e-04
# Epoch 54/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9474 - loss: 3.5635 - val_accuracy: 0.8952 - val_loss: 3.6073 - learning_rate: 1.0000e-04
# Epoch 55/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 420ms/step - accuracy: 0.9363 - loss: 3.4592 - val_accuracy: 0.5514 - val_loss: 4.7167 - learning_rate: 1.0000e-04
# Epoch 56/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 417ms/step - accuracy: 0.9339 - loss: 3.3134 - val_accuracy: 0.9240 - val_loss: 3.2633 - learning_rate: 1.0000e-04
# Epoch 57/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 412ms/step - accuracy: 0.9506 - loss: 3.1652 - val_accuracy: 0.8068 - val_loss: 3.4878 - learning_rate: 1.0000e-04
# Epoch 58/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.9225 - loss: 3.1237 - val_accuracy: 0.9640 - val_loss: 2.8996 - learning_rate: 1.0000e-04
# Epoch 59/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.9527 - loss: 2.9082 - val_accuracy: 0.8861 - val_loss: 2.9930 - learning_rate: 1.0000e-04
# Epoch 60/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 437ms/step - accuracy: 0.9722 - loss: 2.7395 - val_accuracy: 0.9581 - val_loss: 2.6687 - learning_rate: 1.0000e-04
# Epoch 61/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.9572 - loss: 2.6667 - val_accuracy: 0.9352 - val_loss: 2.6472 - learning_rate: 1.0000e-04
# Epoch 62/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.9503 - loss: 2.5611 - val_accuracy: 0.8500 - val_loss: 2.7589 - learning_rate: 1.0000e-04
# Epoch 63/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 432ms/step - accuracy: 0.9454 - loss: 2.4856 - val_accuracy: 0.9358 - val_loss: 2.4371 - learning_rate: 1.0000e-04
# Epoch 64/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 41s 427ms/step - accuracy: 0.9697 - loss: 2.3485 - val_accuracy: 0.8048 - val_loss: 3.1344 - learning_rate: 1.0000e-04
# Epoch 65/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 431ms/step - accuracy: 0.9343 - loss: 2.3200 - val_accuracy: 0.9057 - val_loss: 2.3449 - learning_rate: 1.0000e-04
# Epoch 66/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 431ms/step - accuracy: 0.9575 - loss: 2.1736 - val_accuracy: 0.7354 - val_loss: 2.9010 - learning_rate: 1.0000e-04
# Epoch 67/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.9494 - loss: 2.0796 - val_accuracy: 0.9731 - val_loss: 1.9523 - learning_rate: 1.0000e-04
# Epoch 68/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 434ms/step - accuracy: 0.9852 - loss: 1.9132 - val_accuracy: 0.9889 - val_loss: 1.8192 - learning_rate: 1.0000e-04
# Epoch 69/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 432ms/step - accuracy: 0.9683 - loss: 1.8590 - val_accuracy: 0.9280 - val_loss: 1.9496 - learning_rate: 1.0000e-04
# Epoch 70/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 429ms/step - accuracy: 0.9624 - loss: 1.7962 - val_accuracy: 0.9607 - val_loss: 1.7431 - learning_rate: 1.0000e-04
# Epoch 71/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 432ms/step - accuracy: 0.9768 - loss: 1.7019 - val_accuracy: 0.9044 - val_loss: 1.8501 - learning_rate: 1.0000e-04
# Epoch 72/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.9729 - loss: 1.6319 - val_accuracy: 0.8919 - val_loss: 1.8403 - learning_rate: 1.0000e-04
# Epoch 73/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.9684 - loss: 1.5793 - val_accuracy: 0.9325 - val_loss: 1.6093 - learning_rate: 1.0000e-04
# Epoch 74/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.9672 - loss: 1.4835 - val_accuracy: 0.8337 - val_loss: 1.8743 - learning_rate: 1.0000e-04
# Epoch 75/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.9796 - loss: 1.4134 - val_accuracy: 0.7891 - val_loss: 1.9928 - learning_rate: 1.0000e-04
# Epoch 76/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.9813 - loss: 1.3425 - val_accuracy: 0.8415 - val_loss: 1.7529 - learning_rate: 1.0000e-04
# Epoch 77/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.9658 - loss: 1.3175 - val_accuracy: 0.9817 - val_loss: 1.2237 - learning_rate: 1.0000e-04
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9622 - loss: 1.2450 - val_accuracy: 0.6365 - val_loss: 2.7998 - learning_rate: 1.0000e-04
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.9582 - loss: 1.2323 - val_accuracy: 0.9149 - val_loss: 1.3154 - learning_rate: 1.0000e-04
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.9750 - loss: 1.1249 - val_accuracy: 0.9967 - val_loss: 1.0117 - learning_rate: 1.0000e-04
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.9687 - loss: 1.1021 - val_accuracy: 0.9443 - val_loss: 1.1069 - learning_rate: 1.0000e-04
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 421ms/step - accuracy: 0.9768 - loss: 1.0270 - val_accuracy: 0.9528 - val_loss: 1.0375 - learning_rate: 1.0000e-04
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.9730 - loss: 0.9877 - val_accuracy: 0.9561 - val_loss: 0.9917 - learning_rate: 1.0000e-04
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 24s 437ms/step - accuracy: 0.9861 - loss: 0.9118 - val_accuracy: 0.9921 - val_loss: 0.8513 - learning_rate: 1.0000e-04
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.9730 - loss: 0.9130 - val_accuracy: 0.8998 - val_loss: 1.1381 - learning_rate: 1.0000e-04
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9740 - loss: 0.8565 - val_accuracy: 0.8959 - val_loss: 1.0644 - learning_rate: 1.0000e-04
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.9694 - loss: 0.8386 - val_accuracy: 0.9895 - val_loss: 0.7469 - learning_rate: 1.0000e-04
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 425ms/step - accuracy: 0.9770 - loss: 0.7779 - val_accuracy: 0.8697 - val_loss: 1.1843 - learning_rate: 1.0000e-04
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.9738 - loss: 0.7646 - val_accuracy: 0.9555 - val_loss: 0.7926 - learning_rate: 1.0000e-04
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 422ms/step - accuracy: 0.9675 - loss: 0.7304 - val_accuracy: 0.9489 - val_loss: 0.7688 - learning_rate: 1.0000e-04
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.9758 - loss: 0.6789 - val_accuracy: 0.9535 - val_loss: 0.7208 - learning_rate: 1.0000e-04
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.9828 - loss: 0.6406 - val_accuracy: 0.9856 - val_loss: 0.5971 - learning_rate: 1.0000e-04
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 430ms/step - accuracy: 0.9607 - loss: 0.6716 - val_accuracy: 0.9915 - val_loss: 0.5505 - learning_rate: 1.0000e-04
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.9753 - loss: 0.6258 - val_accuracy: 0.9751 - val_loss: 0.5770 - learning_rate: 1.0000e-04
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 424ms/step - accuracy: 0.9750 - loss: 0.5792 - val_accuracy: 0.9581 - val_loss: 0.6127 - learning_rate: 1.0000e-04
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 427ms/step - accuracy: 0.9772 - loss: 0.5424 - val_accuracy: 0.9876 - val_loss: 0.4994 - learning_rate: 1.0000e-04
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 428ms/step - accuracy: 0.9757 - loss: 0.5408 - val_accuracy: 0.9627 - val_loss: 0.5692 - learning_rate: 1.0000e-04
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 426ms/step - accuracy: 0.9775 - loss: 0.5398 - val_accuracy: 0.9594 - val_loss: 0.5442 - learning_rate: 1.0000e-04
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 423ms/step - accuracy: 0.9825 - loss: 0.4813 - val_accuracy: 0.9935 - val_loss: 0.4200 - learning_rate: 1.0000e-04
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 432ms/step - accuracy: 0.9826 - loss: 0.4607 - val_accuracy: 0.9509 - val_loss: 0.5443 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step
#               precision    recall  f1-score   support
#
#      Aitinyo       1.00      0.98      0.99       374
#      Ayamaru       0.99      1.00      0.99       311
#       Kokoda       0.99      1.00      1.00       302
#          Moi       0.99      1.00      0.99       301
#        Tehit       1.00      1.00      1.00       239
#
#     accuracy                           0.99      1527
#    macro avg       0.99      0.99      0.99      1527
# weighted avg       0.99      0.99      0.99      1527

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

random_index = random.randint(0, len(test_images) - 1)
image = test_images[random_index]
true_label = test_labels[random_index]

prediction = model.predict(np.expand_dims(image, axis=0))[0]
predicted_class_index = np.argmax(prediction)
predicted_class_label = encoder.classes_[predicted_class_index]
confidence = prediction[predicted_class_index]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
plt.imshow(image)
plt.title(f"True Label: {true_label}\nPredicted Label: {predicted_class_label}\nConfidence: {confidence:.2f}")
plt.axis('off')
plt.show()

# %%
import numpy as np

def calculate_mse(original_image, predicted_image):
  """Menghitung MSE antara dua gambar."""
  mse = np.mean((original_image - predicted_image)**2)
  return mse

def calculate_psnr(original_image, predicted_image, max_pixel_value=255.0):
  """Menghitung PSNR antara dua gambar."""
  mse = calculate_mse(original_image, predicted_image)
  if mse == 0:
    psnr = float('inf')  # PSNR tak terhingga jika MSE nol
  else:
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
  return psnr

# Dapatkan gambar asli
original_image = test_images[random_index]

# Lakukan prediksi menggunakan model
prediction = model.predict(np.expand_dims(original_image, axis=0))[0]
predicted_class_index = np.argmax(prediction)
predicted_class_label = encoder.classes_[predicted_class_index]

predicted_image = get_representative_image(predicted_class_label)

# Pastikan dimensi predicted_image sudah benar
predicted_image = cv2.resize(predicted_image, (224, 224))

# Ganti predicted_image dengan gambar yang diprediksi
#prediction_image = prediction
#predicted_image = model.predict(np.expand_dims(original_image, axis=0))[0]  # Sesuaikan dengan output model
#predicted_image = original_image

print("Shape of original_image:", original_image.shape)
print("Shape of predicted_image:", predicted_image.shape)

#mse = calculate_mse(original_image, predicted_image)
#psnr = calculate_psnr(original_image, predicted_image)

#print(f"MSE: {mse:.2f}")
#print(f"PSNR: {psnr:.2f} dB")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6072a76c04e1> in <cell line: 25>()
#      23 predicted_class_label = encoder.classes_[predicted_class_index]
#      24
# ---> 25 predicted_image = get_representative_image(predicted_class_label)
#      26
#      27 # Pastikan dimensi predicted_image sudah benar
#
# NameError: name 'get_representative_image' is not defined
